# %%
import jax.numpy as np
import jax.lax as jl
import jax
import re
import difflib

# %%
def get_mhlo(
        func: callable, 
        *args: object, 
        **kwargs: object
    ) -> str:
    mhlo: str = func.lower(*args, **kwargs).compile().as_text()
    return re.sub("metadata={.*}", "", mhlo)

# %%
def print_diff(mhlo: str, comp: str) -> list:
    mhlo_lines: list = mhlo.splitlines()
    comp_lines: list = comp.splitlines()
    diff: iter = difflib.unified_diff(mhlo_lines, comp_lines)
    for line in diff:
        print(line)

# %%
def mesh(npix: int) -> float:
    centre: float = (npix - 1.0) / 2.0
    shape: tuple =  (1, npix, npix) 
    x: float = jl.broadcasted_iota(float, shape, 1)
    y: float = jl.broadcasted_iota(float, shape, 2)
    return jl.concatenate([x, y], 0) - centre

# %%
def hypotenuse(coordinates: float) -> float:
    pythags: float = jl.integer_pow(coordinates, 2)
    return jl.reduce(pythags, 0., jl.add, [0])

# %%
radius: float = 1.
npix: int = 1024
nsoft: int = 3
x: float = 0.
y: float = 0.
rotation: float = 0.
pixel_scale: float = 2. * radius / npix

# %%
def circ_ap_func(
        radius: float, 
        x: float, 
        y: float,
        rotation: float, 
        nsoft: float,
        pixel_scale: float) -> float:
    # Passing arguments to safe types. 
    centre: float = np.asarray([x, y]).astype(float)
    radius: float = np.asarray(radius).astype(float)
    rotation: float = np.asarray(rotation).astype(float)
    nsoft: float = np.asarray(nsoft).astype(float)
    
    # Organising coords
    ccoords: float = mesh(npix) / npix * 2.0 * radius
    
    # Translation 
    ccoords: float = ccoords - centre[:, None, None]
        
    # Rotation
    sin_alpha: float = jl.sin(rotation)
    cos_alpha: float = jl.cos(rotation)
    x: float = jl.index_in_dim(ccoords, 0)
    y: float = jl.index_in_dim(ccoords, 1)
    new_x: float = x * cos_alpha - y * sin_alpha
    new_y: float = x * sin_alpha + y * cos_alpha
    ccoords: float = jl.concatenate([new_x, new_y], 0)        
        
    # Transformation 
    rho: float = hypotenuse(ccoords)
        
    # Linear softening
    distances: float = radius - rho
    lower: float = jl.full_like(distances, 0., dtype=float)
    upper: float = jl.full_like(distances, 1., dtype=float)
    inside: float = jl.max(distances, lower)
    scaled: float = inside / nsoft / pixel_scale
    aperture: float = jl.min(scaled, upper)
    return aperture

# %%
dynamic: callable = jax.jit(circ_ap_func, inline=True)
static: callable = jax.jit(circ_ap_func, inline=True, static_argnums=(1, 2, 3, 4, 5))

# %%
# %%timeit
dynamic(radius, x, y, rotation, nsoft, pixel_scale).block_until_ready()
# Out:
# 4.4 ms ± 97.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
static(radius, x, y, rotation, nsoft, pixel_scale).block_until_ready()
# Out:
# 4.42 ms ± 174 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
dynamic_mhlo: str = get_mhlo(static, radius, x, y, rotation, nsoft, pixel_scale)
static_mhlo: str = get_mhlo(dynamic, radius, x, y, rotation, nsoft, pixel_scale)

# %%
print_diff(dynamic_mhlo, static_mhlo)
# Out:
# ---
#
# +++
#
# @@ -1,83 +1,112 @@
#
# -HloModule jit_circ_ap_func, entry_computation_layout={(f32[])->f32[1024,1024]{1,0}}, allow_spmd_sharding_propagation_to_output=true
# +HloModule jit_circ_ap_func, entry_computation_layout={(f32[],f32[],f32[],f32[],s32[],f32[])->f32[1024,1024]{1,0}}, allow_spmd_sharding_propagation_to_output=true
#
# -%region_0.40 (Arg_0.41: f32[], Arg_1.42: f32[]) -> f32[] {
# -  %Arg_0.41 = f32[] parameter(0)
# -  %Arg_1.42 = f32[] parameter(1)
# -  ROOT %add.43 = f32[] add(f32[] %Arg_0.41, f32[] %Arg_1.42),
# +%fused_computation.2 (param_0.10: f32[], param_1.18: f32[]) -> f32[2] {
# +  %param_1.18 = f32[] parameter(1)
# +  %reshape.6 = f32[1]{0} reshape(f32[] %param_1.18),
# +  %param_0.10 = f32[] parameter(0)
# +  %reshape.5 = f32[1]{0} reshape(f32[] %param_0.10),
# +  ROOT %concatenate.1 = f32[2]{0} concatenate(f32[1]{0} %reshape.6, f32[1]{0} %reshape.5), dimensions={0},
#  }
#
# -%parallel_reduce.44 (p: f32[2,1024,1024], p.1: f32[]) -> f32[1024,1024] {
# +%region_0.53 (Arg_0.54: f32[], Arg_1.55: f32[]) -> f32[] {
# +  %Arg_0.54 = f32[] parameter(0)
# +  %Arg_1.55 = f32[] parameter(1)
# +  ROOT %add.56 = f32[] add(f32[] %Arg_0.54, f32[] %Arg_1.55),
# +}
# +
# +%parallel_reduce.57 (p: f32[2,1024,1024], p.1: f32[]) -> f32[1024,1024] {
#    %p = f32[2,1024,1024]{2,1,0} parameter(0)
#    %p.1 = f32[] parameter(1)
# -  ROOT %reduce.44.clone = f32[1024,1024]{1,0} reduce(f32[2,1024,1024]{2,1,0} %p, f32[] %p.1), dimensions={0}, to_apply=%region_0.40, "
# +  ROOT %reduce.57.clone = f32[1024,1024]{1,0} reduce(f32[2,1024,1024]{2,1,0} %p, f32[] %p.1), dimensions={0}, to_apply=%region_0.53, "
#  }
#
# -%fused_computation.clone (param_0.14: f32[1024,1024], param_1.19: f32[]) -> f32[1024,1024] {
# -  %param_1.19 = f32[] parameter(1)
# -  %broadcast.28 = f32[1024,1024]{1,0} broadcast(f32[] %param_1.19), dimensions={},
# -  %param_0.14 = f32[1024,1024]{1,0} parameter(0)
# -  %subtract.2 = f32[1024,1024]{1,0} subtract(f32[1024,1024]{1,0} %broadcast.28, f32[1024,1024]{1,0} %param_0.14),
# -  %constant.24 = f32[] constant(0)
# -  %broadcast.27 = f32[1024,1024]{1,0} broadcast(f32[] %constant.24), dimensions={},
# -  %maximum.1 = f32[1024,1024]{1,0} maximum(f32[1024,1024]{1,0} %subtract.2, f32[1024,1024]{1,0} %broadcast.27),
# -  %constant.23 = f32[] constant(170.666672)
# -  %broadcast.26 = f32[1024,1024]{1,0} broadcast(f32[] %constant.23), dimensions={},
# -  %multiply.15 = f32[1024,1024]{1,0} multiply(f32[1024,1024]{1,0} %maximum.1, f32[1024,1024]{1,0} %broadcast.26),
# -  %constant.22 = f32[] constant(1)
# -  %broadcast.25 = f32[1024,1024]{1,0} broadcast(f32[] %constant.22), dimensions={},
# -  ROOT %minimum.1 = f32[1024,1024]{1,0} minimum(f32[1024,1024]{1,0} %multiply.15, f32[1024,1024]{1,0} %broadcast.25),
# +%fused_computation.clone (param_0.12: f32[], param_1.20: s32[], param_2.17: f32[1024,1024], param_3.16: f32[]) -> f32[1024,1024] {
# +  %param_3.16 = f32[] parameter(3)
# +  %broadcast.27 = f32[1024,1024]{1,0} broadcast(f32[] %param_3.16), dimensions={},
# +  %param_2.17 = f32[1024,1024]{1,0} parameter(2)
# +  %subtract.3 = f32[1024,1024]{1,0} subtract(f32[1024,1024]{1,0} %broadcast.27, f32[1024,1024]{1,0} %param_2.17),
# +  %constant.10 = f32[] constant(0)
# +  %broadcast.26 = f32[1024,1024]{1,0} broadcast(f32[] %constant.10), dimensions={},
# +  %maximum.1 = f32[1024,1024]{1,0} maximum(f32[1024,1024]{1,0} %subtract.3, f32[1024,1024]{1,0} %broadcast.26),
# +  %param_1.20 = s32[] parameter(1)
# +  %convert.1 = f32[] convert(s32[] %param_1.20),
# +  %param_0.12 = f32[] parameter(0)
# +  %multiply.15 = f32[] multiply(f32[] %convert.1, f32[] %param_0.12)
# +  %broadcast.24 = f32[1024,1024]{1,0} broadcast(f32[] %multiply.15), dimensions={},
# +  %divide.2 = f32[1024,1024]{1,0} divide(f32[1024,1024]{1,0} %maximum.1, f32[1024,1024]{1,0} %broadcast.24),
# +  %constant.8 = f32[] constant(1)
# +  %broadcast.22 = f32[1024,1024]{1,0} broadcast(f32[] %constant.8), dimensions={},
# +  ROOT %minimum.1 = f32[1024,1024]{1,0} minimum(f32[1024,1024]{1,0} %divide.2, f32[1024,1024]{1,0} %broadcast.22),
#  }
#
# -%parallel_fusion (p.2: f32[1024,1024], p.3: f32[]) -> f32[1024,1024] {
# -  %p.2 = f32[1024,1024]{1,0} parameter(0)
# -  %p.3 = f32[] parameter(1)
# -  ROOT %fusion.clone = f32[1024,1024]{1,0} fusion(f32[1024,1024]{1,0} %p.2, f32[] %p.3), kind=kLoop, calls=%fused_computation.clone, "
# +%parallel_fusion (p.2: f32[], p.3: s32[], p.4: f32[1024,1024], p.5: f32[]) -> f32[1024,1024] {
# +  %p.2 = f32[] parameter(0)
# +  %p.3 = s32[] parameter(1)
# +  %p.4 = f32[1024,1024]{1,0} parameter(2)
# +  %p.5 = f32[] parameter(3)
# +  ROOT %fusion.clone = f32[1024,1024]{1,0} fusion(f32[] %p.2, s32[] %p.3, f32[1024,1024]{1,0} %p.4, f32[] %p.5), kind=kLoop, calls=%fused_computation.clone, "
#  }
#
# -%fused_computation.1.clone (param_0.15: f32[], param_1.20: f32[2,1024,1024]) -> f32[2,1024,1024] {
# -  %param_1.20 = f32[2,1024,1024]{2,1,0} parameter(1)
# -  %constant.27 = f32[] constant(-511.5)
# -  %broadcast.32 = f32[2,1024,1024]{2,1,0} broadcast(f32[] %constant.27), dimensions={}
# -  %add.4 = f32[2,1024,1024]{2,1,0} add(f32[2,1024,1024]{2,1,0} %param_1.20, f32[2,1024,1024]{2,1,0} %broadcast.32),
# -  %param_0.15 = f32[] parameter(0)
# -  %constant.26 = f32[] constant(0.001953125)
# -  %multiply.20 = f32[] multiply(f32[] %param_0.15, f32[] %constant.26),
# -  %broadcast.31 = f32[2,1024,1024]{2,1,0} broadcast(f32[] %multiply.20), dimensions={},
# -  %multiply.19 = f32[2,1024,1024]{2,1,0} multiply(f32[2,1024,1024]{2,1,0} %add.4, f32[2,1024,1024]{2,1,0} %broadcast.31),
# -  %slice.3 = f32[1,1024,1024]{2,1,0} slice(f32[2,1024,1024]{2,1,0} %multiply.19), slice={[0:1], [0:1024], [0:1024]},
# -  %slice.2 = f32[1,1024,1024]{2,1,0} slice(f32[2,1024,1024]{2,1,0} %multiply.19), slice={[1:2], [0:1024], [0:1024]},
# -  %constant.25 = f32[] constant(0)
# -  %broadcast.30 = f32[1,1024,1024]{2,1,0} broadcast(f32[] %constant.25), dimensions={},
# -  %multiply.18 = f32[1,1024,1024]{2,1,0} multiply(f32[1,1024,1024]{2,1,0} %slice.2, f32[1,1024,1024]{2,1,0} %broadcast.30),
# -  %subtract.3 = f32[1,1024,1024]{2,1,0} subtract(f32[1,1024,1024]{2,1,0} %slice.3, f32[1,1024,1024]{2,1,0} %multiply.18),
# -  %multiply.17 = f32[1,1024,1024]{2,1,0} multiply(f32[1,1024,1024]{2,1,0} %slice.3, f32[1,1024,1024]{2,1,0} %broadcast.30),
# -  %add.3 = f32[1,1024,1024]{2,1,0} add(f32[1,1024,1024]{2,1,0} %multiply.17, f32[1,1024,1024]{2,1,0} %slice.2),
# -  %concatenate.2 = f32[2,1024,1024]{2,1,0} concatenate(f32[1,1024,1024]{2,1,0} %subtract.3, f32[1,1024,1024]{2,1,0} %add.3), dimensions={0},
# -  ROOT %multiply.16 = f32[2,1024,1024]{2,1,0} multiply(f32[2,1024,1024]{2,1,0} %concatenate.2, f32[2,1024,1024]{2,1,0} %concatenate.2),
# +%fused_computation.1.clone (param_0.13: f32[], param_1.21: f32[2], param_2.18: f32[], param_3.17: f32[2,1024,1024]) -> f32[2,1024,1024] {
# +  %param_3.17 = f32[2,1024,1024]{2,1,0} parameter(3)
# +  %constant.14 = f32[] constant(-511.5)
# +  %broadcast.34 = f32[2,1024,1024]{2,1,0} broadcast(f32[] %constant.14), dimensions={}
# +  %add.4 = f32[2,1024,1024]{2,1,0} add(f32[2,1024,1024]{2,1,0} %param_3.17, f32[2,1024,1024]{2,1,0} %broadcast.34),
# +  %param_2.18 = f32[] parameter(2)
# +  %constant.12 = f32[] constant(0.001953125)
# +  %multiply.22 = f32[] multiply(f32[] %param_2.18, f32[] %constant.12),
# +  %broadcast.32 = f32[2,1024,1024]{2,1,0} broadcast(f32[] %multiply.22), dimensions={},
# +  %multiply.21 = f32[2,1024,1024]{2,1,0} multiply(f32[2,1024,1024]{2,1,0} %add.4, f32[2,1024,1024]{2,1,0} %broadcast.32),
# +  %param_1.21 = f32[2]{0} parameter(1)
# +  %broadcast.31 = f32[2,1024,1024]{2,1,0} broadcast(f32[2]{0} %param_1.21), dimensions={0},
# +  %subtract.5 = f32[2,1024,1024]{2,1,0} subtract(f32[2,1024,1024]{2,1,0} %multiply.21, f32[2,1024,1024]{2,1,0} %broadcast.31),
# +  %slice.3 = f32[1,1024,1024]{2,1,0} slice(f32[2,1024,1024]{2,1,0} %subtract.5), slice={[0:1], [0:1024], [0:1024]},
# +  %param_0.13 = f32[] parameter(0)
# +  %cosine.1 = f32[] cosine(f32[] %param_0.13),
# +  %broadcast.29 = f32[1,1024,1024]{2,1,0} broadcast(f32[] %cosine.1), dimensions={},
# +  %multiply.20 = f32[1,1024,1024]{2,1,0} multiply(f32[1,1024,1024]{2,1,0} %slice.3, f32[1,1024,1024]{2,1,0} %broadcast.29),
# +  %slice.2 = f32[1,1024,1024]{2,1,0} slice(f32[2,1024,1024]{2,1,0} %subtract.5), slice={[1:2], [0:1024], [0:1024]},
# +  %sine.1 = f32[] sine(f32[] %param_0.13),
# +  %broadcast.28 = f32[1,1024,1024]{2,1,0} broadcast(f32[] %sine.1), dimensions={},
# +  %multiply.19 = f32[1,1024,1024]{2,1,0} multiply(f32[1,1024,1024]{2,1,0} %slice.2, f32[1,1024,1024]{2,1,0} %broadcast.28),
# +  %subtract.4 = f32[1,1024,1024]{2,1,0} subtract(f32[1,1024,1024]{2,1,0} %multiply.20, f32[1,1024,1024]{2,1,0} %multiply.19),
# +  %multiply.18 = f32[1,1024,1024]{2,1,0} multiply(f32[1,1024,1024]{2,1,0} %slice.3, f32[1,1024,1024]{2,1,0} %broadcast.28),
# +  %multiply.17 = f32[1,1024,1024]{2,1,0} multiply(f32[1,1024,1024]{2,1,0} %slice.2, f32[1,1024,1024]{2,1,0} %broadcast.29),
# +  %add.3 = f32[1,1024,1024]{2,1,0} add(f32[1,1024,1024]{2,1,0} %multiply.18, f32[1,1024,1024]{2,1,0} %multiply.17),
# +  %concatenate.3 = f32[2,1024,1024]{2,1,0} concatenate(f32[1,1024,1024]{2,1,0} %subtract.4, f32[1,1024,1024]{2,1,0} %add.3), dimensions={0},
# +  ROOT %multiply.16 = f32[2,1024,1024]{2,1,0} multiply(f32[2,1024,1024]{2,1,0} %concatenate.3, f32[2,1024,1024]{2,1,0} %concatenate.3),
#  }
#
# -%parallel_fusion.1 (p.4: f32[], p.5: f32[2,1024,1024]) -> f32[2,1024,1024] {
# -  %p.4 = f32[] parameter(0)
# -  %p.5 = f32[2,1024,1024]{2,1,0} parameter(1)
# -  ROOT %fusion.1.clone = f32[2,1024,1024]{2,1,0} fusion(f32[] %p.4, f32[2,1024,1024]{2,1,0} %p.5), kind=kLoop, calls=%fused_computation.1.clone, "
# +%parallel_fusion.1 (p.6: f32[], p.7: f32[2], p.8: f32[], p.9: f32[2,1024,1024]) -> f32[2,1024,1024] {
# +  %p.6 = f32[] parameter(0)
# +  %p.7 = f32[2]{0} parameter(1)
# +  %p.8 = f32[] parameter(2)
# +  %p.9 = f32[2,1024,1024]{2,1,0} parameter(3)
# +  ROOT %fusion.1.clone = f32[2,1024,1024]{2,1,0} fusion(f32[] %p.6, f32[2]{0} %p.7, f32[] %p.8, f32[2,1024,1024]{2,1,0} %p.9), kind=kLoop, calls=%fused_computation.1.clone, "
#  }
#
# -%fused_computation.2.clone () -> f32[2,1024,1024] {
# +%fused_computation.3.clone () -> f32[2,1024,1024] {
#    %iota.5 = f32[1,1024,1024]{2,1,0} iota(), iota_dimension=1,
#    %iota.4 = f32[1,1024,1024]{2,1,0} iota(), iota_dimension=2,
# -  ROOT %concatenate.3 = f32[2,1024,1024]{2,1,0} concatenate(f32[1,1024,1024]{2,1,0} %iota.5, f32[1,1024,1024]{2,1,0} %iota.4), dimensions={0},
# +  ROOT %concatenate.4 = f32[2,1024,1024]{2,1,0} concatenate(f32[1,1024,1024]{2,1,0} %iota.5, f32[1,1024,1024]{2,1,0} %iota.4), dimensions={0},
#  }
#
# -%parallel_fusion.2 () -> f32[2,1024,1024] {
# -  ROOT %fusion.2.clone = f32[2,1024,1024]{2,1,0} fusion(), kind=kLoop, calls=%fused_computation.2.clone, "
# +%parallel_fusion.3 () -> f32[2,1024,1024] {
# +  ROOT %fusion.3.clone = f32[2,1024,1024]{2,1,0} fusion(), kind=kLoop, calls=%fused_computation.3.clone, "
#  }
#
# -ENTRY %main.51 (Arg_0.1: f32[]) -> f32[1024,1024] {
# +ENTRY %main.66 (Arg_0.1: f32[], Arg_1.2: f32[], Arg_2.3: f32[], Arg_3.4: f32[], Arg_4.5: s32[], Arg_5.6: f32[]) -> f32[1024,1024] {
# +  %Arg_5.6 = f32[] parameter(5), sharding={replicated},
# +  %Arg_4.5 = s32[] parameter(4), sharding={replicated}
# +  %Arg_3.4 = f32[] parameter(3), sharding={replicated}
# +  %Arg_2.3 = f32[] parameter(2), sharding={replicated}
# +  %Arg_1.2 = f32[] parameter(1), sharding={replicated}
# +  %fusion.2 = f32[2]{0} fusion(f32[] %Arg_2.3, f32[] %Arg_1.2), kind=kLoop, calls=%fused_computation.2,
#    %Arg_0.1 = f32[] parameter(0), sharding={replicated}
# -  %call.3 = f32[2,1024,1024]{2,1,0} call(), to_apply=%parallel_fusion.2
# -  %call.2 = f32[2,1024,1024]{2,1,0} call(f32[] %Arg_0.1, f32[2,1024,1024]{2,1,0} %call.3), to_apply=%parallel_fusion.1
# -  %constant.8 = f32[] constant(0)
# -  %call = f32[1024,1024]{1,0} call(f32[2,1024,1024]{2,1,0} %call.2, f32[] %constant.8), to_apply=%parallel_reduce.44
# -  ROOT %call.1 = f32[1024,1024]{1,0} call(f32[1024,1024]{1,0} %call, f32[] %Arg_0.1), to_apply=%parallel_fusion
# +  %call.3 = f32[2,1024,1024]{2,1,0} call(), to_apply=%parallel_fusion.3
# +  %call.2 = f32[2,1024,1024]{2,1,0} call(f32[] %Arg_3.4, f32[2]{0} %fusion.2, f32[] %Arg_0.1, f32[2,1024,1024]{2,1,0} %call.3), to_apply=%parallel_fusion.1
# +  %constant.9 = f32[] constant(0)
# +  %call = f32[1024,1024]{1,0} call(f32[2,1024,1024]{2,1,0} %call.2, f32[] %constant.9), to_apply=%parallel_reduce.57
# +  ROOT %call.1 = f32[1024,1024]{1,0} call(f32[] %Arg_5.6, s32[] %Arg_4.5, f32[1024,1024]{1,0} %call, f32[] %Arg_0.1), to_apply=%parallel_fusion
#  }
